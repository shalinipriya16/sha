# %% [markdown]
# <a href="https://colab.research.google.com/github/nrjcs/DL_ML/blob/master/PythonIntro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction to Python**

# %%
x=5
print x

x=" Hello World"
print x
print ("hi,", x)
# Out:
# 5
#  Hello World
# ('hi,', ' Hello World')

# %% [markdown]
# # Basic **Datatypes**

# %%
x= 19
y=23.567
z=" We are student of IITP"
w=5j

print type(x)
print type(y)
print type(z)
print type(w)
print z[19:22]

print int(y)
print type(int(y))
# Out:
# <type 'int'>
# <type 'float'>
# <type 'str'>
# <type 'complex'>
# IIT
# 23
# <type 'int'>

# %% [markdown]
# # **List** , Set,  Dictionary

# %%
x=[12,11,10,13]

print "the complete list:", x
print "the particular element:",x[2]
x.pop()
print "the list after popping:", x

x.remove(11)
print "the list after removal specifically:",x

del x[0]
print x

x.append(29)
print "the list after adding:",x

y=[1,34.5,"Python seems fun"]
print "another list--",y
# Out:
# the complete list: [12, 11, 10, 13]
# the particular element: 10
# the list after popping: [12, 11, 10]
# the list after removal specifically: [12, 10]
# [10]
# the list after adding: [10, 29]
# another list-- [1, 34.5, 'Python seems fun']

# %% [markdown]
# Boolean function "in"

# %%
set1={"badminton","cricket","football"}

print set1
print ("cricket" in set1)
print len(set1)

list2=[2,4,5,2,33]
print set(list2)
print len(list(set(list2)))
# Out:
# set(['cricket', 'badminton', 'football'])
# True
# 3
# set([33, 2, 4, 5])
# 4

# %% [markdown]
# Dictionary

# %%
subj =	{
  "name": "Data science",
  "author": "Hadley Wickham",
  "sem": 3
}
print(subj)
print subj["name"]
subj["author"]="Newman"
subj["instructor"]="Sourav Kumar Dandapat"
print subj
# Out:
# {'sem': 3, 'name': 'Data science', 'author': 'Hadley Wickham'}
# Data science
# {'sem': 3, 'instructor': 'Sourav Kumar Dandapat', 'name': 'Data science', 'author': 'Newman'}

# %% [markdown]
# # Decision Making, Loops

# %%
a=[119,23,45,77,13,55]

for i in a:
    print i

print "--------------"
for j in range(len(a)):
      if a[j]>50:
        
        print a[j]
      else:
          continue
# Out:
# 119
# 23
# 45
# 77
# 13
# 55
# --------------
# 119
# 77
# 55

# %% [markdown]
# Assignment
#
# 1. Write python code to create a list that comprises of names of your 5 friends and print the count of number of vowels for each friend.
#
# ex: A=["Radha", "Swati","Raeiya","Rooney"]
#
#
# output:
# Radha----2
#
# Swati ----2
#
# Riya---- 4
#
# Rooney----3

# %% [markdown]
# # Functions

# %%
def find_odd(a):
    if (a%2)!=0:
        print "Hey this is odd!!"
        return a
        
print(find_odd(13))
# Out:
# Hey this is odd!!
# 13

# %% [markdown]
# # Library Functions

# %%
import math

print math.sqrt(1900)
print math.exp(5)
# Out:
# 43.5889894354
# 148.413159103
